# %%
from pandas import Series
from matplotlib import pyplot
series = Series.from_csv('data6.csv', header=0)
print(series.head())
series.plot()
pyplot.show()
# Out:
# Date
# 2014-03-16    6.333333
# 2014-03-16    6.333333
# 2014-03-16    7.000000
# 2014-03-16    6.400000
# 2014-03-16    6.166667
# Name: mood, dtype: float64

# %%
#Tail-rolling average transform
rolling = series.rolling(window=3)
rolling_mean = rolling.mean()
print(rolling_mean.head(10))
# Out:
# Date
# 2014-02-26         NaN
# 2014-02-27         NaN
# 2014-03-04    6.527778
# 2014-03-05    6.555556
# 2014-03-05    7.111111
# 2014-03-06    7.177778
# 2014-03-06    7.483333
# 2014-03-07    7.283333
# 2014-03-07    7.383333
# 2014-03-08    7.300000
# Name: mood, dtype: float64

# %%
# plot original and transformed dataset
series.plot()
rolling_mean.plot(color='red')
pyplot.show()
#raw observations are blue with the moving average transform in red

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
myyearmonth = mdates.DateFormatter('%m/%y')

# %%
data = pd.read_csv('data6.csv')
data.head(10)
data.plot()
pyplot.show()

# %%
rolling = data.rolling(window=5).mean()
rolling.head(10)
# Out:
#          Date      mood   arousal   valence  activity  screentime..s.  \
# 0  2014-03-16       NaN       NaN       NaN       NaN             NaN
# 1  2014-03-16       NaN       NaN       NaN       NaN             NaN
# 2  2014-03-16       NaN       NaN       NaN       NaN             NaN
# 3  2014-03-16       NaN       NaN       NaN       NaN             NaN
# 4  2014-03-16  6.446667 -0.716667  0.356667  0.119059     4781.893192
# 5  2014-03-16  6.500000 -0.876667  0.456667  0.119059     3874.306192
# 6  2014-03-17  6.583333 -0.643333  0.556667  0.128861     4796.650193
# 7  2014-03-17  6.383333 -0.473333  0.386667  0.121723     5431.394393
# 8  2014-03-17  6.183333 -0.273333  0.386667  0.099022     4730.951393
# 9  2014-03-17  6.270000 -0.140000  0.480000  0.099022     4140.758000
#
#     other..s.  travel..s.         buu         coso         enga        fiof  \
# 0         NaN         NaN         NaN          NaN          NaN         NaN
# 1         NaN         NaN         NaN          NaN          NaN         NaN
# 2         NaN         NaN         NaN          NaN          NaN         NaN
# 3         NaN         NaN         NaN          NaN          NaN         NaN
# 4  618.958609  256.420291  985.437211  2967.657337   667.181974  273.032357
# 5  544.967809  256.420291  535.139611  2325.062337   892.425961  222.242285
# 6  547.970609  256.420291  686.311011  2411.298337  1238.595561  222.242285
# 7  566.370009  256.420291  827.439811  2321.530737  1199.837574  222.242285
# 8  106.808409  256.420291  784.625811  4624.794537  1435.167161  222.242285
# 9  211.998200  252.365833  675.426000  4138.841800  1435.167161  222.242285
#
#        teca
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4  3.633293
# 5  3.233293
# 6  3.433293
# 7  2.916647
# 8  2.916647
# 9  3.633293

# %%
from numpy import mean
X = data.values
window = 3
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()

for t in range(len(test)):
    length = len(history)
    for i in range(length-window, window):
        yhat = history[i]

        #yhat = mean([history[i] for i in range(length-3, length)])
